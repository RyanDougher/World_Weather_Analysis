# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Import requests and weather_api_key
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | masuguru
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | saldanha
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | kemijarvi
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 10 of Set 1 | malinyi
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | bambous virieux
# Processing Record 14 of Set 1 | witbank
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | bom jesus da lapa
# Processing Record 17 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 1 | garden city
# Processing Record 19 of Set 1 | rawson
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | high level
# Processing Record 22 of Set 1 | shingu
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | nanortalik
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | susangerd
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | mankachar
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | radford
# Processing Record 32 of Set 1 | torbay
# Processing Record 33 of Set 1 | saint-augustin
# Processing Record 34 of Set 1 | kavieng
# Processing Record 35 of Set 1 | guerrero negro
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | khatanga
# Processing Record 39 of Set 1 | sao joao da barra
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 1 | lumut
# Processing Record 43 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 1 | norman wells
# Processing Record 45 of Set 1 | severo-kurilsk
# Processing Record 46 of Set 1 | vallenar
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | fortuna
# Processing Record 49 of Set 1 | cidreira
# Processing Record 50 of Set 1 | hobart
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | sept-iles
# Processing Record 3 of Set 2 | meulaboh
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | orlik
# Processing Record 7 of Set 2 | iqaluit
# Processing Record 8 of Set 2 | beyneu
# Processing Record 9 of Set 2 | san cristobal
# Processing Record 10 of Set 2 | ewo
# Processing Record 11 of Set 2 | krasnoselkup
# Processing Record 12 of Set 2 | viedma
# Processing Record 13 of Set 2 | gat
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | zig
# Processing Record 17 of Set 2 | salalah
# Processing Record 18 of Set 2 | sulina
# Processing Record 19 of Set 2 | kudahuvadhoo
# Processing Record 20 of Set 2 | broken hill
# Processing Record 21 of Set 2 | upernavik
# Processing Record 22 of Set 2 | singkang
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 2 | vila velha
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | rugeley
# Processing Record 27 of Set 2 | mount gambier
# Processing Record 28 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 2 | puerto madryn
# Processing Record 30 of Set 2 | peace river
# Processing Record 31 of Set 2 | labytnangi
# Processing Record 32 of Set 2 | shakiso
# Processing Record 33 of Set 2 | constitucion
# Processing Record 34 of Set 2 | roald
# Processing Record 35 of Set 2 | flinders
# Processing Record 36 of Set 2 | myitkyina
# Processing Record 37 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 2 | chokurdakh
# Processing Record 39 of Set 2 | natchez
# Processing Record 40 of Set 2 | muravlenko
# Processing Record 41 of Set 2 | shasta lake
# Processing Record 42 of Set 2 | nome
# Processing Record 43 of Set 2 | port lincoln
# Processing Record 44 of Set 2 | aklavik
# Processing Record 45 of Set 2 | port hardy
# Processing Record 46 of Set 2 | chuy
# Processing Record 47 of Set 2 | busselton
# Processing Record 48 of Set 2 | codrington
# Processing Record 49 of Set 2 | mareeba
# Processing Record 50 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 3 | lahij
# Processing Record 2 of Set 3 | simav
# Processing Record 3 of Set 3 | emerald
# Processing Record 4 of Set 3 | provideniya
# Processing Record 5 of Set 3 | banda aceh
# Processing Record 6 of Set 3 | littleton
# Processing Record 7 of Set 3 | portland
# Processing Record 8 of Set 3 | mehamn
# Processing Record 9 of Set 3 | egvekinot
# Processing Record 10 of Set 3 | faanui
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | duayaw nkwanta
# Processing Record 13 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 3 | ponta do sol
# Processing Record 15 of Set 3 | jiroft
# City not found. Skipping...
# Processing Record 16 of Set 3 | san rafael
# Processing Record 17 of Set 3 | dikson
# Processing Record 18 of Set 3 | fare
# Processing Record 19 of Set 3 | castro
# Processing Record 20 of Set 3 | zharkent
# Processing Record 21 of Set 3 | geraldton
# Processing Record 22 of Set 3 | tuktoyaktuk
# Processing Record 23 of Set 3 | vardo
# Processing Record 24 of Set 3 | lasem
# Processing Record 25 of Set 3 | east london
# Processing Record 26 of Set 3 | nanakuli
# Processing Record 27 of Set 3 | atuona
# Processing Record 28 of Set 3 | katsuura
# Processing Record 29 of Set 3 | westport
# Processing Record 30 of Set 3 | yar-sale
# Processing Record 31 of Set 3 | kavaratti
# Processing Record 32 of Set 3 | mahibadhoo
# Processing Record 33 of Set 3 | aykhal
# Processing Record 34 of Set 3 | kruisfontein
# Processing Record 35 of Set 3 | itoman
# Processing Record 36 of Set 3 | polewali
# Processing Record 37 of Set 3 | ahipara
# Processing Record 38 of Set 3 | poum
# Processing Record 39 of Set 3 | klaksvik
# Processing Record 40 of Set 3 | cutler ridge
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | camargo
# Processing Record 43 of Set 3 | arraial do cabo
# Processing Record 44 of Set 3 | broome
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 3 | mbour
# Processing Record 48 of Set 3 | komarno
# Processing Record 49 of Set 3 | wloclawek
# Processing Record 50 of Set 3 | nikolskoye
# Processing Record 1 of Set 4 | morondava
# Processing Record 2 of Set 4 | tasiilaq
# Processing Record 3 of Set 4 | namie
# Processing Record 4 of Set 4 | puerto ayora
# Processing Record 5 of Set 4 | paita
# Processing Record 6 of Set 4 | tiksi
# Processing Record 7 of Set 4 | catia la mar
# Processing Record 8 of Set 4 | souillac
# Processing Record 9 of Set 4 | saint george
# Processing Record 10 of Set 4 | victoria
# Processing Record 11 of Set 4 | aguimes
# Processing Record 12 of Set 4 | hithadhoo
# Processing Record 13 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 14 of Set 4 | senneterre
# Processing Record 15 of Set 4 | warrington
# Processing Record 16 of Set 4 | longyearbyen
# Processing Record 17 of Set 4 | bethel
# Processing Record 18 of Set 4 | okhotsk
# Processing Record 19 of Set 4 | noyabrsk
# Processing Record 20 of Set 4 | mar del plata
# Processing Record 21 of Set 4 | kapaa
# Processing Record 22 of Set 4 | nhulunbuy
# Processing Record 23 of Set 4 | briancon
# Processing Record 24 of Set 4 | pacific grove
# Processing Record 25 of Set 4 | kurumkan
# Processing Record 26 of Set 4 | merauke
# Processing Record 27 of Set 4 | corpus christi
# Processing Record 28 of Set 4 | santa fe
# Processing Record 29 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 4 | zhezkazgan
# Processing Record 31 of Set 4 | camacha
# Processing Record 32 of Set 4 | tra vinh
# Processing Record 33 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 4 | nichinan
# Processing Record 35 of Set 4 | douentza
# Processing Record 36 of Set 4 | nakamura
# Processing Record 37 of Set 4 | praia da vitoria
# Processing Record 38 of Set 4 | vestmannaeyjar
# Processing Record 39 of Set 4 | sao felix do xingu
# Processing Record 40 of Set 4 | phnum penh
# City not found. Skipping...
# Processing Record 41 of Set 4 | santa rosa
# Processing Record 42 of Set 4 | san patricio
# Processing Record 43 of Set 4 | pevek
# Processing Record 44 of Set 4 | bonavista
# Processing Record 45 of Set 4 | saskylakh
# Processing Record 46 of Set 4 | general roca
# Processing Record 47 of Set 4 | mildura
# Processing Record 48 of Set 4 | tura
# Processing Record 49 of Set 4 | hualmay
# Processing Record 50 of Set 4 | lerwick
# Processing Record 1 of Set 5 | naliya
# Processing Record 2 of Set 5 | bengkulu
# Processing Record 3 of Set 5 | luderitz
# Processing Record 4 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 5 of Set 5 | ballina
# Processing Record 6 of Set 5 | kununurra
# Processing Record 7 of Set 5 | talaya
# Processing Record 8 of Set 5 | stupino
# Processing Record 9 of Set 5 | liuzhou
# Processing Record 10 of Set 5 | alice springs
# Processing Record 11 of Set 5 | simao dias
# Processing Record 12 of Set 5 | sapai
# City not found. Skipping...
# Processing Record 13 of Set 5 | akureyri
# Processing Record 14 of Set 5 | amealco
# Processing Record 15 of Set 5 | awbari
# Processing Record 16 of Set 5 | sur
# Processing Record 17 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 5 | khulo
# Processing Record 19 of Set 5 | muyezerskiy
# Processing Record 20 of Set 5 | price
# Processing Record 21 of Set 5 | half moon bay
# Processing Record 22 of Set 5 | bardiyah
# Processing Record 23 of Set 5 | magdagachi
# Processing Record 24 of Set 5 | pangkalanbuun
# Processing Record 25 of Set 5 | vanimo
# Processing Record 26 of Set 5 | hasaki
# Processing Record 27 of Set 5 | gornopravdinsk
# Processing Record 28 of Set 5 | eureka
# Processing Record 29 of Set 5 | uruzgan
# Processing Record 30 of Set 5 | grindavik
# Processing Record 31 of Set 5 | coihaique
# Processing Record 32 of Set 5 | coquimbo
# Processing Record 33 of Set 5 | alekseyevka
# Processing Record 34 of Set 5 | sumenep
# Processing Record 35 of Set 5 | bay roberts
# Processing Record 36 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 5 | central point
# Processing Record 38 of Set 5 | dickinson
# Processing Record 39 of Set 5 | finschhafen
# Processing Record 40 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 41 of Set 5 | kenora
# Processing Record 42 of Set 5 | majene
# Processing Record 43 of Set 5 | north vanlaiphai
# Processing Record 44 of Set 5 | impfondo
# Processing Record 45 of Set 5 | berekum
# Processing Record 46 of Set 5 | camposampiero
# Processing Record 47 of Set 5 | ukiah
# Processing Record 48 of Set 5 | sighisoara
# City not found. Skipping...
# Processing Record 49 of Set 5 | sanmenxia
# Processing Record 50 of Set 5 | qui nhon
# Processing Record 1 of Set 6 | mahebourg
# Processing Record 2 of Set 6 | diamantino
# Processing Record 3 of Set 6 | arua
# Processing Record 4 of Set 6 | nizhniy kuranakh
# Processing Record 5 of Set 6 | barcelos
# Processing Record 6 of Set 6 | camacupa
# Processing Record 7 of Set 6 | thompson
# Processing Record 8 of Set 6 | tessalit
# Processing Record 9 of Set 6 | bowmore
# Processing Record 10 of Set 6 | sisimiut
# Processing Record 11 of Set 6 | chotepe
# Processing Record 12 of Set 6 | ketchikan
# Processing Record 13 of Set 6 | cherskiy
# Processing Record 14 of Set 6 | kahului
# Processing Record 15 of Set 6 | noblesville
# Processing Record 16 of Set 6 | el badari
# City not found. Skipping...
# Processing Record 17 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 18 of Set 6 | azua
# Processing Record 19 of Set 6 | saravan
# Processing Record 20 of Set 6 | zheleznodorozhnyy
# Processing Record 21 of Set 6 | lompoc
# Processing Record 22 of Set 6 | mundo nuevo
# Processing Record 23 of Set 6 | zhigansk
# Processing Record 24 of Set 6 | richard toll
# City not found. Skipping...
# Processing Record 25 of Set 6 | namibe
# Processing Record 26 of Set 6 | gangapur
# Processing Record 27 of Set 6 | chumikan
# Processing Record 28 of Set 6 | udachnyy
# Processing Record 29 of Set 6 | thanh hoa
# Processing Record 30 of Set 6 | nuuk
# Processing Record 31 of Set 6 | acapulco
# Processing Record 32 of Set 6 | shahrud
# Processing Record 33 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 6 | sijunjung
# Processing Record 36 of Set 6 | jacmel
# Processing Record 37 of Set 6 | axim
# Processing Record 38 of Set 6 | bilma
# Processing Record 39 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 40 of Set 6 | yulara
# Processing Record 41 of Set 6 | benguela
# Processing Record 42 of Set 6 | bathsheba
# Processing Record 43 of Set 6 | zverinogolovskoye
# Processing Record 44 of Set 6 | ulladulla
# Processing Record 45 of Set 6 | severnyy
# Processing Record 46 of Set 6 | nipawin
# Processing Record 47 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 48 of Set 6 | laguna
# Processing Record 49 of Set 6 | sola
# Processing Record 50 of Set 6 | encrucijada
# Processing Record 1 of Set 7 | rzhev
# Processing Record 2 of Set 7 | nyandoma
# Processing Record 3 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 4 of Set 7 | sabang
# Processing Record 5 of Set 7 | faya
# Processing Record 6 of Set 7 | san-pedro
# Processing Record 7 of Set 7 | belmonte
# Processing Record 8 of Set 7 | husavik
# Processing Record 9 of Set 7 | wamba
# Processing Record 10 of Set 7 | vangaindrano
# Processing Record 11 of Set 7 | cabo san lucas
# Processing Record 12 of Set 7 | liverpool
# Processing Record 13 of Set 7 | muros
# Processing Record 14 of Set 7 | serebryansk
# Processing Record 15 of Set 7 | miandrivazo
# Processing Record 16 of Set 7 | kysyl-syr
# Processing Record 17 of Set 7 | raudeberg
# Processing Record 18 of Set 7 | necochea
# Processing Record 19 of Set 7 | el campo
# Processing Record 20 of Set 7 | kondinskoye
# Processing Record 21 of Set 7 | ifanadiana
# Processing Record 22 of Set 7 | sitka
# Processing Record 23 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 7 | dingle
# Processing Record 25 of Set 7 | esperance
# Processing Record 26 of Set 7 | waipawa
# Processing Record 27 of Set 7 | urucara
# Processing Record 28 of Set 7 | mastic beach
# Processing Record 29 of Set 7 | yerbogachen
# Processing Record 30 of Set 7 | lavrentiya
# Processing Record 31 of Set 7 | ovalle
# Processing Record 32 of Set 7 | kuminskiy
# Processing Record 33 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 34 of Set 7 | sao filipe
# Processing Record 35 of Set 7 | roswell
# Processing Record 36 of Set 7 | ishigaki
# Processing Record 37 of Set 7 | dedougou
# Processing Record 38 of Set 7 | bogo
# Processing Record 39 of Set 7 | walvis bay
# Processing Record 40 of Set 7 | dawlatabad
# Processing Record 41 of Set 7 | formosa
# Processing Record 42 of Set 7 | ponnani
# Processing Record 43 of Set 7 | bandar-e anzali
# Processing Record 44 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 7 | soe
# Processing Record 46 of Set 7 | kyren
# Processing Record 47 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 7 | port elizabeth
# Processing Record 49 of Set 7 | hay river
# Processing Record 50 of Set 7 | kalach-na-donu
# Processing Record 1 of Set 8 | buta
# Processing Record 2 of Set 8 | mazara del vallo
# Processing Record 3 of Set 8 | ciudad real
# Processing Record 4 of Set 8 | srednekolymsk
# Processing Record 5 of Set 8 | mandalgovi
# Processing Record 6 of Set 8 | polovinnoye
# Processing Record 7 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 8 | xining
# Processing Record 10 of Set 8 | yalutorovsk
# Processing Record 11 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 8 | vasilkovo
# City not found. Skipping...
# Processing Record 13 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 14 of Set 8 | los llanos de aridane
# Processing Record 15 of Set 8 | flagstaff
# Processing Record 16 of Set 8 | garmsar
# Processing Record 17 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 8 | shelburne
# Processing Record 19 of Set 8 | umm kaddadah
# Processing Record 20 of Set 8 | qaanaaq
# Processing Record 21 of Set 8 | ranibennur
# Processing Record 22 of Set 8 | pangnirtung
# Processing Record 23 of Set 8 | dongkan
# Processing Record 24 of Set 8 | itarema
# Processing Record 25 of Set 8 | charters towers
# Processing Record 26 of Set 8 | lakes entrance
# Processing Record 27 of Set 8 | khandyga
# Processing Record 28 of Set 8 | sydney
# Processing Record 29 of Set 8 | alyangula
# Processing Record 30 of Set 8 | itajai
# Processing Record 31 of Set 8 | chabahar
# Processing Record 32 of Set 8 | turayf
# Processing Record 33 of Set 8 | yanam
# Processing Record 34 of Set 8 | lagoa
# Processing Record 35 of Set 8 | hervey bay
# Processing Record 36 of Set 8 | shimoda
# Processing Record 37 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 8 | pandan
# Processing Record 39 of Set 8 | airai
# Processing Record 40 of Set 8 | koraput
# Processing Record 41 of Set 8 | prince george
# Processing Record 42 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 8 | manadhoo
# Processing Record 44 of Set 8 | huangmei
# Processing Record 45 of Set 8 | grootfontein
# Processing Record 46 of Set 8 | salta
# Processing Record 47 of Set 8 | christchurch
# Processing Record 48 of Set 8 | vila
# Processing Record 49 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 50 of Set 8 | dunedin
# Processing Record 1 of Set 9 | port moresby
# Processing Record 2 of Set 9 | japura
# Processing Record 3 of Set 9 | carbondale
# Processing Record 4 of Set 9 | palmer
# Processing Record 5 of Set 9 | okato
# Processing Record 6 of Set 9 | huarmey
# Processing Record 7 of Set 9 | darhan
# Processing Record 8 of Set 9 | olafsvik
# Processing Record 9 of Set 9 | asau
# Processing Record 10 of Set 9 | tupancireta
# Processing Record 11 of Set 9 | goderich
# Processing Record 12 of Set 9 | ancud
# Processing Record 13 of Set 9 | oskarshamn
# Processing Record 14 of Set 9 | estrella
# Processing Record 15 of Set 9 | ormara
# Processing Record 16 of Set 9 | natal
# Processing Record 17 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 9 | beringovskiy
# Processing Record 19 of Set 9 | mount isa
# Processing Record 20 of Set 9 | hami
# Processing Record 21 of Set 9 | champerico
# Processing Record 22 of Set 9 | puerto quijarro
# Processing Record 23 of Set 9 | qaqortoq
# Processing Record 24 of Set 9 | hoi an
# Processing Record 25 of Set 9 | saint anthony
# Processing Record 26 of Set 9 | touros
# Processing Record 27 of Set 9 | binga
# Processing Record 28 of Set 9 | koumac
# Processing Record 29 of Set 9 | gbadolite
# Processing Record 30 of Set 9 | nuevitas
# Processing Record 31 of Set 9 | belaya gora
# Processing Record 32 of Set 9 | oyama
# Processing Record 33 of Set 9 | gazanjyk
# Processing Record 34 of Set 9 | foumban
# Processing Record 35 of Set 9 | moron
# Processing Record 36 of Set 9 | hobyo
# Processing Record 37 of Set 9 | aberdeen
# Processing Record 38 of Set 9 | manta
# Processing Record 39 of Set 9 | datong
# Processing Record 40 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 9 | general pico
# Processing Record 42 of Set 9 | husyatyn
# Processing Record 43 of Set 9 | sabzevar
# Processing Record 44 of Set 9 | joshimath
# Processing Record 45 of Set 9 | inhambane
# Processing Record 46 of Set 9 | port blair
# Processing Record 47 of Set 9 | narsaq
# Processing Record 48 of Set 9 | baykit
# Processing Record 49 of Set 9 | arman
# Processing Record 50 of Set 9 | rovaniemi
# Processing Record 1 of Set 10 | badami
# Processing Record 2 of Set 10 | bonthe
# Processing Record 3 of Set 10 | kaliua
# Processing Record 4 of Set 10 | eirunepe
# Processing Record 5 of Set 10 | stolin
# Processing Record 6 of Set 10 | singapore
# Processing Record 7 of Set 10 | jalu
# Processing Record 8 of Set 10 | kerema
# Processing Record 9 of Set 10 | solnechnyy
# Processing Record 10 of Set 10 | vieques
# Processing Record 11 of Set 10 | muli
# Processing Record 12 of Set 10 | barquisimeto
# Processing Record 13 of Set 10 | sokoto
# Processing Record 14 of Set 10 | leningradskiy
# Processing Record 15 of Set 10 | lucapa
# Processing Record 16 of Set 10 | deputatskiy
# Processing Record 17 of Set 10 | bosaso
# Processing Record 18 of Set 10 | kourou
# Processing Record 19 of Set 10 | anadyr
# Processing Record 20 of Set 10 | alice town
# Processing Record 21 of Set 10 | yining
# Processing Record 22 of Set 10 | fredericton
# Processing Record 23 of Set 10 | marawi
# Processing Record 24 of Set 10 | luang prabang
# Processing Record 25 of Set 10 | davila
# Processing Record 26 of Set 10 | suhbaatar
# Processing Record 27 of Set 10 | kautokeino
# Processing Record 28 of Set 10 | guicheng
# City not found. Skipping...
# Processing Record 29 of Set 10 | waggaman
# Processing Record 30 of Set 10 | ust-kuyga
# Processing Record 31 of Set 10 | gamba
# Processing Record 32 of Set 10 | englehart
# Processing Record 33 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 10 | visnes
# Processing Record 35 of Set 10 | margate
# Processing Record 36 of Set 10 | tuatapere
# Processing Record 37 of Set 10 | vao
# Processing Record 38 of Set 10 | kolokani
# Processing Record 39 of Set 10 | colac
# Processing Record 40 of Set 10 | grand gaube
# Processing Record 41 of Set 10 | xinyang
# Processing Record 42 of Set 10 | pembroke
# Processing Record 43 of Set 10 | front royal
# Processing Record 44 of Set 10 | manokwari
# Processing Record 45 of Set 10 | askino
# Processing Record 46 of Set 10 | isangel
# Processing Record 47 of Set 10 | domna
# Processing Record 48 of Set 10 | ndele
# Processing Record 49 of Set 10 | teguise
# Processing Record 50 of Set 10 | mporokoso
# Processing Record 1 of Set 11 | sorland
# Processing Record 2 of Set 11 | teknaf
# Processing Record 3 of Set 11 | madang
# Processing Record 4 of Set 11 | sooke
# Processing Record 5 of Set 11 | luau
# Processing Record 6 of Set 11 | karasjok
# Processing Record 7 of Set 11 | naze
# Processing Record 8 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 9 of Set 11 | salinopolis
# Processing Record 10 of Set 11 | marzuq
# Processing Record 11 of Set 11 | mackay
# Processing Record 12 of Set 11 | xam nua
# Processing Record 13 of Set 11 | san quintin
# Processing Record 14 of Set 11 | komagane
# Processing Record 15 of Set 11 | sobolevo
# Processing Record 16 of Set 11 | inuvik
# Processing Record 17 of Set 11 | krasnoturansk
# Processing Record 18 of Set 11 | sambava
# Processing Record 19 of Set 11 | te anau
# Processing Record 20 of Set 11 | kindu
# Processing Record 21 of Set 11 | sochi
# Processing Record 22 of Set 11 | matadi
# Processing Record 23 of Set 11 | surt
# Processing Record 24 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 11 | saint-denis
# Processing Record 26 of Set 11 | chernyshevskiy
# Processing Record 27 of Set 11 | yambio
# Processing Record 28 of Set 11 | yaan
# Processing Record 29 of Set 11 | roma
# Processing Record 30 of Set 11 | merta
# Processing Record 31 of Set 11 | garden grove
# Processing Record 32 of Set 11 | zvishavane
# Processing Record 33 of Set 11 | najran
# Processing Record 34 of Set 11 | pitimbu
# Processing Record 35 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 11 | mahajanga
# Processing Record 38 of Set 11 | barreirinhas
# Processing Record 39 of Set 11 | kosa
# Processing Record 40 of Set 11 | hofn
# Processing Record 41 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 11 | fountain hills
# Processing Record 43 of Set 11 | santa branca
# Processing Record 44 of Set 11 | plouzane
# Processing Record 45 of Set 11 | jaciara
# Processing Record 46 of Set 11 | iskandar
# Processing Record 47 of Set 11 | mayumba
# Processing Record 48 of Set 11 | santarem
# Processing Record 49 of Set 11 | xingcheng
# Processing Record 50 of Set 11 | vanavara
# Processing Record 1 of Set 12 | kushmurun
# Processing Record 2 of Set 12 | zyryanka
# Processing Record 3 of Set 12 | edgewater
# Processing Record 4 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 5 of Set 12 | kachug
# Processing Record 6 of Set 12 | yatou
# Processing Record 7 of Set 12 | prescott
# Processing Record 8 of Set 12 | sirnak
# Processing Record 9 of Set 12 | bac lieu
# Processing Record 10 of Set 12 | gold coast
# Processing Record 11 of Set 12 | boca do acre
# Processing Record 12 of Set 12 | kirakira
# Processing Record 13 of Set 12 | calvia
# Processing Record 14 of Set 12 | seymchan
# Processing Record 15 of Set 12 | belyy yar
# Processing Record 16 of Set 12 | megion
# Processing Record 17 of Set 12 | arkhangelos
# City not found. Skipping...
# Processing Record 18 of Set 12 | kota kinabalu
# Processing Record 19 of Set 12 | miracema do tocantins
# Processing Record 20 of Set 12 | jaisalmer
# Processing Record 21 of Set 12 | tual
# Processing Record 22 of Set 12 | white rock
# Processing Record 23 of Set 12 | sao miguel do tapuio
# Processing Record 24 of Set 12 | kozyatyn
# Processing Record 25 of Set 12 | mwanza
# Processing Record 26 of Set 12 | tautira
# Processing Record 27 of Set 12 | shediac
# Processing Record 28 of Set 12 | aswan
# Processing Record 29 of Set 12 | imeni poliny osipenko
# Processing Record 30 of Set 12 | elat
# Processing Record 31 of Set 12 | miramar
# Processing Record 32 of Set 12 | ayan
# Processing Record 33 of Set 12 | chifeng
# Processing Record 34 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 12 | boyolangu
# Processing Record 36 of Set 12 | tarragona
# Processing Record 37 of Set 12 | yamada
# Processing Record 38 of Set 12 | college
# Processing Record 39 of Set 12 | poso
# Processing Record 40 of Set 12 | vila franca do campo
# Processing Record 41 of Set 12 | auxerre
# Processing Record 42 of Set 12 | alofi
# Processing Record 43 of Set 12 | namatanai
# Processing Record 44 of Set 12 | vitim
# Processing Record 45 of Set 12 | new richmond
# Processing Record 46 of Set 12 | sistranda
# Processing Record 47 of Set 12 | gorno-altaysk
# Processing Record 48 of Set 12 | pundaguitan
# Processing Record 49 of Set 12 | uyuni
# Processing Record 50 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 13 | takoradi
# Processing Record 2 of Set 13 | tlaxco
# Processing Record 3 of Set 13 | mnogovershinnyy
# Processing Record 4 of Set 13 | yendi
# Processing Record 5 of Set 13 | aldan
# Processing Record 6 of Set 13 | urumqi
# Processing Record 7 of Set 13 | cerqueira cesar
# Processing Record 8 of Set 13 | saint-brieuc
# Processing Record 9 of Set 13 | mugumu
# Processing Record 10 of Set 13 | ilulissat
# Processing Record 11 of Set 13 | bednodemyanovsk
# City not found. Skipping...
# Processing Record 12 of Set 13 | marsh harbour
# Processing Record 13 of Set 13 | lavumisa
# Processing Record 14 of Set 13 | peniche
# Processing Record 15 of Set 13 | haapu
# City not found. Skipping...
# Processing Record 16 of Set 13 | pokhara
# Processing Record 17 of Set 13 | kashi
# Processing Record 18 of Set 13 | truro
# Processing Record 19 of Set 13 | farafangana
# Processing Record 20 of Set 13 | northam
# Processing Record 21 of Set 13 | arlit
# Processing Record 22 of Set 13 | norden
# Processing Record 23 of Set 13 | saint-joseph
# Processing Record 24 of Set 13 | saint-ambroise
# Processing Record 25 of Set 13 | channel-port aux basques
# Processing Record 26 of Set 13 | volksrust
# Processing Record 27 of Set 13 | guntakal
# Processing Record 28 of Set 13 | caernarfon
# Processing Record 29 of Set 13 | noumea
# Processing Record 30 of Set 13 | minna
# Processing Record 31 of Set 13 | buala
# Processing Record 32 of Set 13 | port hedland
# Processing Record 33 of Set 13 | loreto
# Processing Record 34 of Set 13 | hammerfest
# Processing Record 35 of Set 13 | lebedyn
# Processing Record 36 of Set 13 | progreso
# Processing Record 37 of Set 13 | comodoro rivadavia
# Processing Record 38 of Set 13 | guangyuan
# Processing Record 39 of Set 13 | oyonnax
# Processing Record 40 of Set 13 | charleston
# Processing Record 41 of Set 13 | hamilton
# Processing Record 42 of Set 13 | waitati
# Processing Record 43 of Set 13 | portsmouth
# Processing Record 44 of Set 13 | sharjah
# Processing Record 45 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 46 of Set 13 | la uribe
# City not found. Skipping...
# Processing Record 47 of Set 13 | panama city
# Processing Record 48 of Set 13 | cochrane
# Processing Record 49 of Set 13 | barentu
# Processing Record 50 of Set 13 | zemen
# Processing Record 1 of Set 14 | praxedis guerrero
# Processing Record 2 of Set 14 | barra do garcas
# Processing Record 3 of Set 14 | saryozek
# Processing Record 4 of Set 14 | kuytun
# Processing Record 5 of Set 14 | novyy urengoy
# Processing Record 6 of Set 14 | minas
# Processing Record 7 of Set 14 | talcahuano
# Processing Record 8 of Set 14 | sindor
# Processing Record 9 of Set 14 | tateyama
# Processing Record 10 of Set 14 | gasa
# Processing Record 11 of Set 14 | kucevo
# Processing Record 12 of Set 14 | lata
# Processing Record 13 of Set 14 | ankazobe
# Processing Record 14 of Set 14 | barmer
# Processing Record 15 of Set 14 | sikeston
# Processing Record 16 of Set 14 | tianpeng
# Processing Record 17 of Set 14 | kritsa
# Processing Record 18 of Set 14 | talnakh
# Processing Record 19 of Set 14 | poya
# Processing Record 20 of Set 14 | hailar
# Processing Record 21 of Set 14 | oktyabrskiy
# Processing Record 22 of Set 14 | basoko
# Processing Record 23 of Set 14 | simacota
# Processing Record 24 of Set 14 | novaya malykla
# Processing Record 25 of Set 14 | bandarbeyla
# Processing Record 26 of Set 14 | north las vegas
# Processing Record 27 of Set 14 | phulpur
# Processing Record 28 of Set 14 | linxia
# Processing Record 29 of Set 14 | tucuman
# Processing Record 30 of Set 14 | bageshwar
# Processing Record 31 of Set 14 | sorong
# Processing Record 32 of Set 14 | burnie
# Processing Record 33 of Set 14 | beboto
# Processing Record 34 of Set 14 | umm lajj
# Processing Record 35 of Set 14 | karlshamn
# Processing Record 36 of Set 14 | tuy hoa
# Processing Record 37 of Set 14 | zyryanskoye
# Processing Record 38 of Set 14 | clyde river
# Processing Record 39 of Set 14 | makurdi
# Processing Record 40 of Set 14 | clarence town
# Processing Record 41 of Set 14 | fasa
# Processing Record 42 of Set 14 | saint-pierre
# Processing Record 43 of Set 14 | gobabis
# Processing Record 44 of Set 14 | jacareacanga
# Processing Record 45 of Set 14 | maputo
# Processing Record 46 of Set 14 | outjo
# Processing Record 47 of Set 14 | leogane
# Processing Record 48 of Set 14 | liberal
# Processing Record 49 of Set 14 | siavonga
# Processing Record 50 of Set 14 | sedona
# Processing Record 1 of Set 15 | reconquista
# Processing Record 2 of Set 15 | pimentel
# Processing Record 3 of Set 15 | taltal
# Processing Record 4 of Set 15 | primero de enero
# Processing Record 5 of Set 15 | arivonimamo
# Processing Record 6 of Set 15 | kuroiso
# Processing Record 7 of Set 15 | luganville
# Processing Record 8 of Set 15 | labuhan
# Processing Record 9 of Set 15 | beira
# Processing Record 10 of Set 15 | cayenne
# Processing Record 11 of Set 15 | kutum
# Processing Record 12 of Set 15 | planeta rica
# Processing Record 13 of Set 15 | calnic
# Processing Record 14 of Set 15 | san andres
# Processing Record 15 of Set 15 | nuevo progreso
# Processing Record 16 of Set 15 | birao
# Processing Record 17 of Set 15 | soldotna
# Processing Record 18 of Set 15 | warrnambool
# Processing Record 19 of Set 15 | imuris
# Processing Record 20 of Set 15 | helena
# Processing Record 21 of Set 15 | pryozerne
# Processing Record 22 of Set 15 | chiredzi
# Processing Record 23 of Set 15 | el tigre
# Processing Record 24 of Set 15 | lamu
# Processing Record 25 of Set 15 | iracoubo
# Processing Record 26 of Set 15 | polson
# Processing Record 27 of Set 15 | touho
# Processing Record 28 of Set 15 | longuenesse
# Processing Record 29 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 15 | fort-shevchenko
# Processing Record 31 of Set 15 | inirida
# Processing Record 32 of Set 15 | conceicao do araguaia
# Processing Record 33 of Set 15 | carutapera
# Processing Record 34 of Set 15 | la gaulette
# City not found. Skipping...
# Processing Record 35 of Set 15 | moussoro
# Processing Record 36 of Set 15 | volot
# Processing Record 37 of Set 15 | am timan
# Processing Record 38 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 15 | rincon
# Processing Record 40 of Set 15 | acari
# Processing Record 41 of Set 15 | havelock
# Processing Record 42 of Set 15 | kropotkin
# Processing Record 43 of Set 15 | marsa matruh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 680

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Masuguru      TZ -11.3667   38.4167     71.69        99         100
# 1          Avarua      CK -21.2078 -159.7750     80.65        78          75
# 2        Saldanha      ZA -33.0117   17.9442     65.53        88          96
# 3     New Norfolk      AU -42.7826  147.0587     63.75        57          99
# 4       Kemijarvi      FI  66.7131   27.4306     -7.31       100          45
# 5  Ribeira Grande      PT  38.5167  -28.7000     61.30        88         100
# 6         Rikitea      PF -23.1203 -134.9692     79.32        69           1
# 7         Malinyi      TZ  -8.9333   36.1333     71.13        98         100
# 8       Cape Town      ZA -33.9258   18.4232     70.09        78         100
# 9       Jamestown      US  42.0970  -79.2353     27.09        63         100
#
#    Wind Speed Current Description
# 0        3.74          light rain
# 1        4.61       broken clouds
# 2       13.96     overcast clouds
# 3        4.72     overcast clouds
# 4        2.28    scattered clouds
# 5       15.64     overcast clouds
# 6       18.16          light rain
# 7        2.55          light rain
# 8        4.00     overcast clouds
# 9        9.22     overcast clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
